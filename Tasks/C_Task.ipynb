# %% [markdown]
# # Project: Build a Regression Model in Keras
#
# ## Task C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# ### Install and Import Packages

# %%
# %pip install numpy
# %pip install pandas
# %pip install keras
# %pip install scikit-learn
# %pip install tensorflow
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Setup, Train, and Test Model with 100 Epochs

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')

def regression_model():
    model = Sequential()
    model.add(Dense(10, activation='relu'))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

model = regression_model()

concrete_data_columns = concrete_data.columns
target = concrete_data['Strength']
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']]
predictors_norm = (predictors - predictors.mean()) / predictors.std()

model.fit(predictors_norm, target, validation_split=0.3, epochs=50, verbose=2)

num_iterations = 100
mse_values = []

for _ in range(num_iterations):
    x_train, x_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)
    y_pred = model.predict(x_test)
    y_pred_aggregate = np.mean(y_pred, axis=1)
    mse_value = mean_squared_error(y_test, y_pred_aggregate)
    mse_values.append(mse_value)

mean_mse = np.mean(mse_values)
std_mse = np.std(mse_values)
print(f"Mean squared error: {mean_mse}")
print(f"Standard deviation of MSE: {std_mse}")
# Out:
# Epoch 1/50
# 23/23 - 0s - loss: 1673.4257 - val_loss: 1211.3202 - 182ms/epoch - 8ms/step
# Epoch 2/50
# 23/23 - 0s - loss: 1670.6272 - val_loss: 1209.9979 - 25ms/epoch - 1ms/step
# Epoch 3/50
# 23/23 - 0s - loss: 1667.7654 - val_loss: 1208.6107 - 25ms/epoch - 1ms/step
# Epoch 4/50
# 23/23 - 0s - loss: 1664.8577 - val_loss: 1207.2391 - 23ms/epoch - 1ms/step
# Epoch 5/50
# 23/23 - 0s - loss: 1661.8383 - val_loss: 1205.8101 - 22ms/epoch - 940us/step
# Epoch 6/50
# 23/23 - 0s - loss: 1658.7394 - val_loss: 1204.3661 - 21ms/epoch - 927us/step
# Epoch 7/50
# 23/23 - 0s - loss: 1655.5721 - val_loss: 1202.9148 - 22ms/epoch - 956us/step
# Epoch 8/50
# 23/23 - 0s - loss: 1652.4265 - val_loss: 1201.5198 - 22ms/epoch - 942us/step
# Epoch 9/50
# 23/23 - 0s - loss: 1649.1808 - val_loss: 1200.1064 - 22ms/epoch - 941us/step
# Epoch 10/50
# 23/23 - 0s - loss: 1645.9736 - val_loss: 1198.6306 - 21ms/epoch - 907us/step
# Epoch 11/50
# ...

# %% [markdown]
# The MSE of Task B and Task C are very close despite the epochs being different. The standard deviation is 2.27 in Task C though whereas Task B it is 0.
